# %% [markdown]
# # HOMEWORK

# %%
from PIL import Image

# %%
img=Image.open("katu.jpg")

# %%
img_1=Image.open("katu.jpg")

# %%
img_1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x320>

# %%
print(img_1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x320 at 0x1083AAE90>

# %%
img_1.resize((80,106))
# Out:
# <PIL.Image.Image image mode=RGB size=80x106>

# %%
img_1.transpose(Image.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=240x320>

# %%
from PIL import ImageGrab

# %%
img_2=ImageGrab.grab()

# %%
print(img_2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2940x1912 at 0x10953E0D0>

# %%
img_2.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=2940x1912>

# %%
img.crop((1350,796,1470,956))
# Out:
# <PIL.Image.Image image mode=RGB size=120x160>

# %%
img_2.paste(img,(1350,796,1470,956))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 img_2.paste(img,(1350,796,1470,956))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/PIL/Image.py:1809, in Image.paste(self, im, box, mask)
#    1807     self.im.paste(source, box, mask.im)
#    1808 else:
# -> 1809     self.im.paste(source, box)
#
# ValueError: images do not match

# %%
img_2.save("screen.png")
