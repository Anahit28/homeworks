# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler

from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# %%
path="mushrooms"
train = pd.read_csv(os.path.join(path, "train.csv"))
test = pd.read_csv(os.path.join(path, "test.csv"))
ss = pd.read_csv(os.path.join(path, "sample_submission.csv"))

# %%
train.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116945 entries, 0 to 3116944
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   class                 object
#  2   cap-diameter          float64
#  3   cap-shape             object
#  4   cap-surface           object
#  5   cap-color             object
#  6   does-bruise-or-bleed  object
#  7   gill-attachment       object
#  8   gill-spacing          object
#  9   gill-color            object
#  10  stem-height           float64
#  11  stem-width            float64
#  12  stem-root             object
#  13  stem-surface          object
#  14  stem-color            object
#  15  veil-type             object
#  16  veil-color            object
#  17  has-ring              object
#  18  ring-type             object
#  19  spore-print-color     object
#  20  habitat               object
#  21  season                object
# dtypes: float64(3), int64(1), object(18)
# memory usage: 2.4 GB

# %%
train
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 3116940  3116940     e          9.29         f         NaN         n
# 3116941  3116941     e         10.88         s         NaN         w
# 3116942  3116942     p          7.82         x           e         e
# 3116943  3116943     e          9.45         p           i         n
# 3116944  3116944     p          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 1                          f               a            c          n  ...
# 2                          f               x            c          w  ...
# 3                          f               s          NaN          g  ...
# 4                          f               d          NaN          w  ...
# ...                      ...             ...          ...        ...  ...
# 3116940                    t             NaN          NaN          w  ...
# 3116941                    t               d            c          p  ...
# 3116942                    f               a          NaN          w  ...
# 3116943                    t               e          NaN          p  ...
# 3116944                    f               d            c          w  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0              NaN           NaN          w       NaN        NaN        f
# 1              NaN             y          o       NaN        NaN        t
# 2              NaN             s          n       NaN        NaN        f
# 3              NaN           NaN          w       NaN        NaN        f
# 4              NaN           NaN          w       NaN        NaN        f
# ...            ...           ...        ...       ...        ...      ...
# 3116940          b           NaN          w         u          w        t
# 3116941        NaN           NaN          w       NaN        NaN        f
# 3116942        NaN           NaN          y       NaN          w        t
# 3116943        NaN             y          w       NaN        NaN        t
# 3116944        NaN           NaN          w       NaN        NaN        f
#
#         ring-type spore-print-color habitat season
# 0               f               NaN       d      a
# 1               z               NaN       d      w
# 2               f               NaN       l      w
# 3               f               NaN       d      u
# 4               f               NaN       g      a
# ...           ...               ...     ...    ...
# 3116940         g               NaN       d      u
# 3116941         f               NaN       d      u
# 3116942         z               NaN       d      a
# 3116943         p               NaN       d      u
# 3116944         f               NaN       g      u
#
# [3116945 rows x 22 columns]

# %%
train.isna().sum() / len(train) * 100
# Out:
# id                       0.000000
# class                    0.000000
# cap-diameter             0.000128
# cap-shape                0.001283
# cap-surface             21.528227
# cap-color                0.000385
# does-bruise-or-bleed     0.000257
# gill-attachment         16.809280
# gill-spacing            40.373988
# gill-color               0.001829
# stem-height              0.000000
# stem-width               0.000000
# stem-root               88.452732
# stem-surface            63.551362
# stem-color               0.001219
# veil-type               94.884350
# veil-color              87.936970
# has-ring                 0.000770
# ring-type                4.134818
# spore-print-color       91.425482
# habitat                  0.001444
# season                   0.000000
# dtype: float64

# %%
train["class"].value_counts()
# Out:
# class
# p    1705396
# e    1411549
# Name: count, dtype: int64

# %%
train.drop(["id", "stem-root", "stem-surface", "veil-type", "veil-color", "spore-print-color"], axis=1, inplace=True)

# %%
y = (train["class"] == "p").astype("int8").values
x = train.drop("class", axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
info = {}

# %%
x_train
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 1249285          6.11         b           y         w                    f
# 1952332         10.42         s           t         w                    t
# 2912806          1.86         f           i         l                    f
# 136822           8.65         s           d         w                    f
# 552456           4.86         x           y         g                    f
# ...               ...       ...         ...       ...                  ...
# 2249467          8.96         p         NaN         n                    f
# 963395           7.39         x           s         b                    f
# 2215104          1.94         b         NaN         g                    f
# 1484405          3.58         x           s         w                    f
# 305711           7.23         x           s         n                    f
#
#         gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# 1249285             NaN          NaN          k        12.72       16.36
# 1952332               d            c          o         6.73       17.74
# 2912806               a          NaN          w         3.63        2.46
# 136822                s            c          w         7.82       28.50
# 552456                s          NaN          y         5.57       11.25
# ...                 ...          ...        ...          ...         ...
# 2249467               p          NaN          w         9.34       27.54
# 963395                d            d          b         5.99       12.80
# 2215104               a          NaN          g         5.41        2.12
# 1484405               d            c          w         3.47        8.04
# 305711                e            c          g         4.94       12.64
#
#         stem-color has-ring ring-type habitat season
# 1249285          w        f         f       d      a
# 1952332          w        f         f       d      a
# 2912806          w        f         f       d      u
# 136822           w        f         f       d      u
# 552456           w        f         f       d      u
# ...            ...      ...       ...     ...    ...
# 2249467          n        f         f       d      a
# 963395           w        f         f       d      w
# 2215104          g        f         f       d      a
# 1484405          w        f         f       d      u
# 305711           w        t         r       m      u
#
# [2337708 rows x 15 columns]

# %%
m = x_train["cap-diameter"].mean()
info["cap-diameter_mean"] = m

x_train["cap-diameter"].fillna(m, inplace=True)

x_train["cap-diameter"] = x_train["cap-diameter"].astype("float32")
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/1724415823.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["cap-diameter"].fillna(m, inplace=True)

# %%
train["cap-shape"].value_counts()[:15]
# Out:
# cap-shape
# x    1436026
# f     676238
# s     365146
# b     318646
# o     108835
# p     106967
# c     104520
# d         65
# e         60
# n         41
# t         36
# w         36
# g         34
# y         33
# r         32
# Name: count, dtype: int64

# %%
info["cap-shape_val"] = "x"
x_train["cap-shape"].fillna("x", inplace=True)
info["cap_shape_keys"] = list(x_train["cap-shape"].value_counts()[:4].index)
for k in info["cap_shape_keys"]:
    x_train[f"cap_shape_{k}"] = (x_train["cap-shape"] == k).astype("int8")
x_train[f"cap_shape_other"] = (~x_train["cap-shape"].isin(info["cap_shape_keys"])).astype("int8")
x_train.drop("cap-shape", axis=1, inplace=True)
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/3874554285.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["cap-shape"].fillna("x", inplace=True)

# %%
x_train
# Out:
#          cap-diameter cap-surface cap-color does-bruise-or-bleed  \
# 1249285          6.11           y         w                    f
# 1952332         10.42           t         w                    t
# 2912806          1.86           i         l                    f
# 136822           8.65           d         w                    f
# 552456           4.86           y         g                    f
# ...               ...         ...       ...                  ...
# 2249467          8.96         NaN         n                    f
# 963395           7.39           s         b                    f
# 2215104          1.94         NaN         g                    f
# 1484405          3.58           s         w                    f
# 305711           7.23           s         n                    f
#
#         gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# 1249285             NaN          NaN          k        12.72       16.36
# 1952332               d            c          o         6.73       17.74
# 2912806               a          NaN          w         3.63        2.46
# 136822                s            c          w         7.82       28.50
# 552456                s          NaN          y         5.57       11.25
# ...                 ...          ...        ...          ...         ...
# 2249467               p          NaN          w         9.34       27.54
# 963395                d            d          b         5.99       12.80
# 2215104               a          NaN          g         5.41        2.12
# 1484405               d            c          w         3.47        8.04
# 305711                e            c          g         4.94       12.64
#
#         stem-color has-ring ring-type habitat season  cap_shape_x  \
# 1249285          w        f         f       d      a            0
# 1952332          w        f         f       d      a            0
# 2912806          w        f         f       d      u            0
# 136822           w        f         f       d      u            0
# 552456           w        f         f       d      u            1
# ...            ...      ...       ...     ...    ...          ...
# 2249467          n        f         f       d      a            0
# 963395           w        f         f       d      w            1
# 2215104          g        f         f       d      a            0
# 1484405          w        f         f       d      u            1
# 305711           w        t         r       m      u            1
#
#          cap_shape_f  cap_shape_s  cap_shape_b  cap_shape_other
# 1249285            0            0            1                0
# 1952332            0            1            0                0
# 2912806            1            0            0                0
# 136822             0            1            0                0
# 552456             0            0            0                0
# ...              ...          ...          ...              ...
# 2249467            0            0            0                1
# 963395             0            0            0                0
# 2215104            0            0            1                0
# 1484405            0            0            0                0
# 305711             0            0            0                0
#
# [2337708 rows x 19 columns]

# %%
x_train["cap-surface"].isna().sum()
# Out:
# np.int64(502664)

# %%
cap_surface_dict = x_train["cap-surface"].value_counts(normalize=True)[:11]
cap_surface_dict = cap_surface_dict / cap_surface_dict.sum()
info["cap_surface_dict"] = cap_surface_dict
cap_surface_dict
# Out:
# cap-surface
# t    0.188261
# s    0.157622
# y    0.134050
# h    0.116445
# g    0.107736
# d    0.084486
# k    0.052713
# e    0.048919
# i    0.046416
# w    0.045012
# l    0.018341
# Name: proportion, dtype: float64

# %%
def cp(x):
    if isinstance(x, float) and np.isnan(x):
        return np.random.choice(cap_surface_dict.index, p=cap_surface_dict.values)
    elif np.isin(x, cap_surface_dict.index):
        return x
    else:
        return "other"

# %%
x_train["cap-surface-clean"]=x_train["cap-surface"].apply(cp)

# %%
x_train["cap-color"].isna().sum()
# Out:
# np.int64(9)

# %%
x_train["cap-color"].value_counts()[:15]
# Out:
# cap-color
# n    1019646
# y     290275
# w     284478
# g     157839
# e     147888
# o     134231
# p      69112
# r      58686
# u      54864
# b      46040
# k      44901
# l      29467
# d         41
# f         40
# s         33
# Name: count, dtype: int64

# %%
cap_color_dict = x_train["cap-color"].value_counts(normalize=True)[:6]
cap_color_dict = cap_color_dict / cap_color_dict.sum()
info["cap_color_dict"] = cap_color_dict
def cc(x):
    if isinstance(x, float) and np.isnan(x):
        return np.random.choice(cap_color_dict.index, p=cap_color_dict.values)
    elif np.isin(x, cap_color_dict.index):
        return x
    else:
        return "other"

# %%
x_train["cap-color-clean"]=x_train["cap-color"].apply(cp)

# %%
x_train
# Out:
#          cap-diameter cap-surface cap-color does-bruise-or-bleed  \
# 1249285          6.11           y         w                    f
# 1952332         10.42           t         w                    t
# 2912806          1.86           i         l                    f
# 136822           8.65           d         w                    f
# 552456           4.86           y         g                    f
# ...               ...         ...       ...                  ...
# 2249467          8.96         NaN         n                    f
# 963395           7.39           s         b                    f
# 2215104          1.94         NaN         g                    f
# 1484405          3.58           s         w                    f
# 305711           7.23           s         n                    f
#
#         gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# 1249285             NaN          NaN          k        12.72       16.36
# 1952332               d            c          o         6.73       17.74
# 2912806               a          NaN          w         3.63        2.46
# 136822                s            c          w         7.82       28.50
# 552456                s          NaN          y         5.57       11.25
# ...                 ...          ...        ...          ...         ...
# 2249467               p          NaN          w         9.34       27.54
# 963395                d            d          b         5.99       12.80
# 2215104               a          NaN          g         5.41        2.12
# 1484405               d            c          w         3.47        8.04
# 305711                e            c          g         4.94       12.64
#
#         stem-color  ... ring-type habitat season cap_shape_x  cap_shape_f  \
# 1249285          w  ...         f       d      a           0            0
# 1952332          w  ...         f       d      a           0            0
# 2912806          w  ...         f       d      u           0            1
# 136822           w  ...         f       d      u           0            0
# 552456           w  ...         f       d      u           1            0
# ...            ...  ...       ...     ...    ...         ...          ...
# 2249467          n  ...         f       d      a           0            0
# 963395           w  ...         f       d      w           1            0
# 2215104          g  ...         f       d      a           0            0
# 1484405          w  ...         f       d      u           1            0
# 305711           w  ...         r       m      u           1            0
#
#          cap_shape_s  cap_shape_b  cap_shape_other  cap-surface-clean  \
# 1249285            0            1                0                  y
# 1952332            1            0                0                  t
# 2912806            0            0                0                  i
# 136822             1            0                0                  d
# 552456             0            0                0                  y
# ...              ...          ...              ...                ...
# 2249467            0            0                1                  w
# 963395             0            0                0                  s
# 2215104            0            1                0                  i
# 1484405            0            0                0                  s
# 305711             0            0                0                  s
#
#         cap-color-clean
# 1249285               w
# 1952332               w
# 2912806               l
# 136822                w
# 552456                g
# ...                 ...
# 2249467           other
# 963395            other
# 2215104               g
# 1484405               w
# 305711            other
#
# [2337708 rows x 21 columns]

# %%
x_train.drop(["cap-surface","cap-color"],axis=1,inplace=True)

# %%
x_train
# Out:
#          cap-diameter does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                    f             NaN          NaN
# 1952332         10.42                    t               d            c
# 2912806          1.86                    f               a          NaN
# 136822           8.65                    f               s            c
# 552456           4.86                    f               s          NaN
# ...               ...                  ...             ...          ...
# 2249467          8.96                    f               p          NaN
# 963395           7.39                    f               d            d
# 2215104          1.94                    f               a          NaN
# 1484405          3.58                    f               d            c
# 305711           7.23                    f               e            c
#
#         gill-color  stem-height  stem-width stem-color has-ring ring-type  \
# 1249285          k        12.72       16.36          w        f         f
# 1952332          o         6.73       17.74          w        f         f
# 2912806          w         3.63        2.46          w        f         f
# 136822           w         7.82       28.50          w        f         f
# 552456           y         5.57       11.25          w        f         f
# ...            ...          ...         ...        ...      ...       ...
# 2249467          w         9.34       27.54          n        f         f
# 963395           b         5.99       12.80          w        f         f
# 2215104          g         5.41        2.12          g        f         f
# 1484405          w         3.47        8.04          w        f         f
# 305711           g         4.94       12.64          w        t         r
#
#         habitat season  cap_shape_x  cap_shape_f  cap_shape_s  cap_shape_b  \
# 1249285       d      a            0            0            0            1
# 1952332       d      a            0            0            1            0
# 2912806       d      u            0            1            0            0
# 136822        d      u            0            0            1            0
# 552456        d      u            1            0            0            0
# ...         ...    ...          ...          ...          ...          ...
# 2249467       d      a            0            0            0            0
# 963395        d      w            1            0            0            0
# 2215104       d      a            0            0            0            1
# 1484405       d      u            1            0            0            0
# 305711        m      u            1            0            0            0
#
#          cap_shape_other cap-surface-clean cap-color-clean
# 1249285                0                 y               w
# 1952332                0                 t               w
# 2912806                0                 i               l
# 136822                 0                 d               w
# 552456                 0                 y               g
# ...                  ...               ...             ...
# 2249467                1                 w           other
# 963395                 0                 s           other
# 2215104                0                 i               g
# 1484405                0                 s               w
# 305711                 0                 s           other
#
# [2337708 rows x 19 columns]

# %%
x_train["does-bruise-or-bleed"].isna().sum()
# Out:
# np.int64(7)

# %%
x_train.columns
# Out:
# Index(['cap-diameter', 'does-bruise-or-bleed', 'gill-attachment',
#        'gill-spacing', 'gill-color', 'stem-height', 'stem-width', 'stem-color',
#        'has-ring', 'ring-type', 'habitat', 'season', 'cap_shape_x',
#        'cap_shape_f', 'cap_shape_s', 'cap_shape_b', 'cap_shape_other',
#        'cap-surface-clean', 'cap-color-clean'],
#       dtype='object')

# %%
most_freq = x_train["does-bruise-or-bleed"].mode()[0]
x_train["does-bruise-or-bleed"].fillna(most_freq, inplace=True)
info["does-bruise-or-bleed_most_freq"] = most_freq
x_train["does-bruise-or-bleed"] = (x_train["does-bruise-or-bleed"] == "t").astype("int8")
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/2255316462.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["does-bruise-or-bleed"].fillna(most_freq, inplace=True)

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0             NaN          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color  stem-height  stem-width stem-color has-ring ring-type  \
# 1249285          k        12.72       16.36          w        f         f
# 1952332          o         6.73       17.74          w        f         f
# 2912806          w         3.63        2.46          w        f         f
# 136822           w         7.82       28.50          w        f         f
# 552456           y         5.57       11.25          w        f         f
# ...            ...          ...         ...        ...      ...       ...
# 2249467          w         9.34       27.54          n        f         f
# 963395           b         5.99       12.80          w        f         f
# 2215104          g         5.41        2.12          g        f         f
# 1484405          w         3.47        8.04          w        f         f
# 305711           g         4.94       12.64          w        t         r
#
#         habitat season  cap_shape_x  cap_shape_f  cap_shape_s  cap_shape_b  \
# 1249285       d      a            0            0            0            1
# 1952332       d      a            0            0            1            0
# 2912806       d      u            0            1            0            0
# 136822        d      u            0            0            1            0
# 552456        d      u            1            0            0            0
# ...         ...    ...          ...          ...          ...          ...
# 2249467       d      a            0            0            0            0
# 963395        d      w            1            0            0            0
# 2215104       d      a            0            0            0            1
# 1484405       d      u            1            0            0            0
# 305711        m      u            1            0            0            0
#
#          cap_shape_other cap-surface-clean cap-color-clean
# 1249285                0                 y               w
# 1952332                0                 t               w
# 2912806                0                 i               l
# 136822                 0                 d               w
# 552456                 0                 y               g
# ...                  ...               ...             ...
# 2249467                1                 w           other
# 963395                 0                 s           other
# 2215104                0                 i               g
# 1484405                0                 s               w
# 305711                 0                 s           other
#
# [2337708 rows x 19 columns]

# %%
x_train["gill-attachment"].value_counts()[:30]
# Out:
# gill-attachment
# a            484150
# d            441860
# x            270491
# e            226407
# s            221743
# p            209511
# f             90209
# c                56
# u                38
# w                28
# k                27
# t                26
# y                24
# i                20
# o                16
# b                16
# m                16
# g                15
# h                14
# n                12
# l                11
# r                 8
# season            5
# z                 5
# 1.32              1
# does None         1
# 13.15             1
# 13.94             1
# 3.91              1
# p p               1
# Name: count, dtype: int64

# %%
gill_att_dict = x_train["gill-attachment"].value_counts(normalize=True)[:6]
gill_att_dict = gill_att_dict/ gill_att_dict.sum()
info["gill-attachment-dict"] = gill_att_dict
def ga(x):
    if isinstance(x, float) and np.isnan(x):
        return np.random.choice(gill_att_dict.index, p=gill_att_dict.values)
    elif np.isin(x, gill_att_dict.index):
        return x
    else:
        return "other"

# %%
x_train["gill-attachment-clean"]=x_train["gill-attachment"].apply(ga)

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0             NaN          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color  stem-height  stem-width stem-color has-ring ring-type  \
# 1249285          k        12.72       16.36          w        f         f
# 1952332          o         6.73       17.74          w        f         f
# 2912806          w         3.63        2.46          w        f         f
# 136822           w         7.82       28.50          w        f         f
# 552456           y         5.57       11.25          w        f         f
# ...            ...          ...         ...        ...      ...       ...
# 2249467          w         9.34       27.54          n        f         f
# 963395           b         5.99       12.80          w        f         f
# 2215104          g         5.41        2.12          g        f         f
# 1484405          w         3.47        8.04          w        f         f
# 305711           g         4.94       12.64          w        t         r
#
#         habitat season  cap_shape_x  cap_shape_f  cap_shape_s  cap_shape_b  \
# 1249285       d      a            0            0            0            1
# 1952332       d      a            0            0            1            0
# 2912806       d      u            0            1            0            0
# 136822        d      u            0            0            1            0
# 552456        d      u            1            0            0            0
# ...         ...    ...          ...          ...          ...          ...
# 2249467       d      a            0            0            0            0
# 963395        d      w            1            0            0            0
# 2215104       d      a            0            0            0            1
# 1484405       d      u            1            0            0            0
# 305711        m      u            1            0            0            0
#
#          cap_shape_other cap-surface-clean cap-color-clean  \
# 1249285                0                 y               w
# 1952332                0                 t               w
# 2912806                0                 i               l
# 136822                 0                 d               w
# 552456                 0                 y               g
# ...                  ...               ...             ...
# 2249467                1                 w           other
# 963395                 0                 s           other
# 2215104                0                 i               g
# 1484405                0                 s               w
# 305711                 0                 s           other
#
#         gill-attachment-clean
# 1249285                     x
# 1952332                     d
# 2912806                     a
# 136822                      s
# 552456                      s
# ...                       ...
# 2249467                     p
# 963395                      d
# 2215104                     a
# 1484405                     d
# 305711                      e
#
# [2337708 rows x 20 columns]

# %%
x_train["gill-spacing"].isna().sum()
# Out:
# np.int64(943723)

# %%
x_train["gill-spacing"].value_counts()[:20]
# Out:
# gill-spacing
# c       997939
# d       306171
# f        89771
# e           14
# s           13
# a           13
# b           11
# p            6
# x            5
# t            4
# l            3
# k            3
# h            3
# 0            2
# y            2
# 1.88         1
# i            1
# 4.09         1
# 6.67         1
# 3.81         1
# Name: count, dtype: int64

# %%
gill_sp_dict = x_train["gill-spacing"].value_counts(normalize=True)[:6]
gill_sp_dict = gill_sp_dict/ gill_sp_dict.sum()
info["gill-spacing-dict"] = gill_sp_dict
def gs(x):
    if isinstance(x, float) and np.isnan(x):
        return np.random.choice(gill_sp_dict.index, p=gill_sp_dict.values)
    elif np.isin(x, gill_sp_dict.index):
        return x
    else:
        return "other"

# %%
x_train["gill-spacing-clean"]=x_train["gill-spacing"].apply(gs)

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0             NaN          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color  stem-height  stem-width stem-color has-ring ring-type  \
# 1249285          k        12.72       16.36          w        f         f
# 1952332          o         6.73       17.74          w        f         f
# 2912806          w         3.63        2.46          w        f         f
# 136822           w         7.82       28.50          w        f         f
# 552456           y         5.57       11.25          w        f         f
# ...            ...          ...         ...        ...      ...       ...
# 2249467          w         9.34       27.54          n        f         f
# 963395           b         5.99       12.80          w        f         f
# 2215104          g         5.41        2.12          g        f         f
# 1484405          w         3.47        8.04          w        f         f
# 305711           g         4.94       12.64          w        t         r
#
#          ... season cap_shape_x  cap_shape_f  cap_shape_s  cap_shape_b  \
# 1249285  ...      a           0            0            0            1
# 1952332  ...      a           0            0            1            0
# 2912806  ...      u           0            1            0            0
# 136822   ...      u           0            0            1            0
# 552456   ...      u           1            0            0            0
# ...      ...    ...         ...          ...          ...          ...
# 2249467  ...      a           0            0            0            0
# 963395   ...      w           1            0            0            0
# 2215104  ...      a           0            0            0            1
# 1484405  ...      u           1            0            0            0
# 305711   ...      u           1            0            0            0
#
#          cap_shape_other  cap-surface-clean cap-color-clean  \
# 1249285                0                  y               w
# 1952332                0                  t               w
# 2912806                0                  i               l
# 136822                 0                  d               w
# 552456                 0                  y               g
# ...                  ...                ...             ...
# 2249467                1                  w           other
# 963395                 0                  s           other
# 2215104                0                  i               g
# 1484405                0                  s               w
# 305711                 0                  s           other
#
#         gill-attachment-clean gill-spacing-clean
# 1249285                     x                  c
# 1952332                     d                  c
# 2912806                     a                  d
# 136822                      s                  c
# 552456                      s                  c
# ...                       ...                ...
# 2249467                     p                  c
# 963395                      d                  d
# 2215104                     a                  c
# 1484405                     d                  c
# 305711                      e                  c
#
# [2337708 rows x 21 columns]

# %%
x_train["gill-color"].isna().sum()
# Out:
# np.int64(35)

# %%
gill_c_dict = x_train["gill-color"].value_counts(normalize=True)[:6]
gill_c_dict = gill_c_dict/ gill_c_dict.sum()
info["gill-color-dict"] = gill_c_dict
def gc(x):
    if isinstance(x, float) and np.isnan(x):
        return np.random.choice(gill_c_dict.index, p=gill_c_dict.values)
    elif np.isin(x, gill_c_dict.index):
        return x
    else:
        return "other"

# %%
x_train["gill-color-clean"]=x_train["gill-color"].apply(gc)

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0             NaN          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color  stem-height  stem-width stem-color has-ring ring-type  \
# 1249285          k        12.72       16.36          w        f         f
# 1952332          o         6.73       17.74          w        f         f
# 2912806          w         3.63        2.46          w        f         f
# 136822           w         7.82       28.50          w        f         f
# 552456           y         5.57       11.25          w        f         f
# ...            ...          ...         ...        ...      ...       ...
# 2249467          w         9.34       27.54          n        f         f
# 963395           b         5.99       12.80          w        f         f
# 2215104          g         5.41        2.12          g        f         f
# 1484405          w         3.47        8.04          w        f         f
# 305711           g         4.94       12.64          w        t         r
#
#          ... cap_shape_x cap_shape_f  cap_shape_s  cap_shape_b  \
# 1249285  ...           0           0            0            1
# 1952332  ...           0           0            1            0
# 2912806  ...           0           1            0            0
# 136822   ...           0           0            1            0
# 552456   ...           1           0            0            0
# ...      ...         ...         ...          ...          ...
# 2249467  ...           0           0            0            0
# 963395   ...           1           0            0            0
# 2215104  ...           0           0            0            1
# 1484405  ...           1           0            0            0
# 305711   ...           1           0            0            0
#
#          cap_shape_other  cap-surface-clean  cap-color-clean  \
# 1249285                0                  y                w
# 1952332                0                  t                w
# 2912806                0                  i                l
# 136822                 0                  d                w
# 552456                 0                  y                g
# ...                  ...                ...              ...
# 2249467                1                  w            other
# 963395                 0                  s            other
# 2215104                0                  i                g
# 1484405                0                  s                w
# 305711                 0                  s            other
#
#         gill-attachment-clean gill-spacing-clean gill-color-clean
# 1249285                     x                  c            other
# 1952332                     d                  c                o
# 2912806                     a                  d                w
# 136822                      s                  c                w
# 552456                      s                  c                y
# ...                       ...                ...              ...
# 2249467                     p                  c                w
# 963395                      d                  d            other
# 2215104                     a                  c                g
# 1484405                     d                  c                w
# 305711                      e                  c                g
#
# [2337708 rows x 22 columns]

# %%
train.drop(["gill-attachment", "gill-spacing", "gill-color"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[290], line 1
# ----> 1 train.drop(["gill-attachment", "gill-spacing", "gill-color"], axis=1, inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['gill-attachment', 'gill-spacing'] not found in axis"

# %%
x_train["stem-height"].isna().sum()
# Out:
# np.int64(0)

# %%
x_train["stem-height"]=x_train["stem-height"]/x_train["stem-height"].sum()
info["stem-height_dict"]=x_train["stem-height"].values

# %%
x_train["stem-width"].isna().sum()
# Out:
# np.int64(0)

# %%
x_train["stem-width"]=x_train["stem-width"]/x_train["stem-width"].sum()
info["stem-width_dict"]=x_train["stem-width"].values

# %%
x_train["stem-color"].isna().sum()
# Out:
# np.int64(28)

# %%
x_train["stem-color"].value_counts()[:15]
# Out:
# stem-color
# w    896774
# n    753274
# y    280796
# g     98636
# o     83667
# e     77687
# u     50110
# p     41116
# k     25286
# r     16724
# l      7454
# b      5522
# f       433
# s        38
# t        32
# Name: count, dtype: int64

# %%
info["stem-color-dict"] = "w"
x_train["stem-color"].fillna("w", inplace=True)
info["stem-color-dict"] = list(x_train["stem-color"].value_counts()[:3].index)
for k in info["stem-color-dict"]:
    x_train[f"stem-color-{k}"] = (x_train["stem-color"] == k).astype("int8")
x_train[f"stem-color"] = (~x_train["stem-color"].isin(info["stem-color-dict"])).astype("int8")
x_train.drop("stem-color", axis=1, inplace=True)
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/3216049661.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["stem-color"].fillna("w", inplace=True)

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0             NaN          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color   stem-height    stem-width has-ring ring-type habitat  \
# 1249285          k  8.571480e-07  6.271031e-07        f         f       d
# 1952332          o  4.535067e-07  6.800005e-07        f         f       d
# 2912806          w  2.446106e-07  9.429545e-08        f         f       d
# 136822           w  5.269573e-07  1.092447e-06        f         f       d
# 552456           y  3.753392e-07  4.312292e-07        f         f       d
# ...            ...           ...           ...      ...       ...     ...
# 2249467          w  6.293838e-07  1.055649e-06        f         f       d
# 963395           b  4.036412e-07  4.906430e-07        f         f       d
# 2215104          g  3.645574e-07  8.126275e-08        f         f       d
# 1484405          w  2.338289e-07  3.081851e-07        f         f       d
# 305711           g  3.328861e-07  4.845100e-07        t         r       m
#
#          ... cap_shape_b  cap_shape_other  cap-surface-clean  cap-color-clean  \
# 1249285  ...           1                0                  y                w
# 1952332  ...           0                0                  t                w
# 2912806  ...           0                0                  i                l
# 136822   ...           0                0                  d                w
# 552456   ...           0                0                  y                g
# ...      ...         ...              ...                ...              ...
# 2249467  ...           0                1                  w            other
# 963395   ...           0                0                  s            other
# 2215104  ...           1                0                  i                g
# 1484405  ...           0                0                  s                w
# 305711   ...           0                0                  s            other
#
#          gill-attachment-clean  gill-spacing-clean gill-color-clean  \
# 1249285                      x                   c            other
# 1952332                      d                   c                o
# 2912806                      a                   d                w
# 136822                       s                   c                w
# 552456                       s                   c                y
# ...                        ...                 ...              ...
# 2249467                      p                   c                w
# 963395                       d                   d            other
# 2215104                      a                   c                g
# 1484405                      d                   c                w
# 305711                       e                   c                g
#
#         stem-color-w stem-color-n stem-color-y
# 1249285            1            0            0
# 1952332            1            0            0
# 2912806            1            0            0
# 136822             1            0            0
# 552456             1            0            0
# ...              ...          ...          ...
# 2249467            0            1            0
# 963395             1            0            0
# 2215104            0            0            0
# 1484405            1            0            0
# 305711             1            0            0
#
# [2337708 rows x 24 columns]

# %%
has_ring_mf = x_train["has-ring"].mode()[0]
x_train["has-ring"].fillna(has_ring_mf, inplace=True)
info["has-ring_most_freq"] = has_ring_mf
x_train["has-ring_flag"] = (x_train["has-ring"] == "t").astype("int8")
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/3607637510.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["has-ring"].fillna(has_ring_mf, inplace=True)

# %%
x_train["ring-type"].fillna("n", inplace=True)
info["ring-type_most_freq"] = "n"
info["ring-type_keys"] = list(x_train["ring-type"].value_counts()[:3].index)
for k in info["ring-type_keys"]:
    x_train[f"ring-type_{k}"] = (x_train["ring-type"] == k).astype("int8")
x_train["ring-type_other"] = (~x_train["ring-type"].isin(info["ring-type_keys"])).astype("int8")
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/1458785647.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["ring-type"].fillna("n", inplace=True)

# %%
# Train
most_freq = x_train["habitat"].mode()[0]  
x_train["habitat"].fillna(most_freq, inplace=True)
info["habitat_most_freq"] = most_freq
info["habitat_keys"] = list(x_train["habitat"].value_counts()[:4].index)
for k in info["habitat_keys"]:
    x_train[f"habitat_{k}"] = (x_train["habitat"] == k).astype("int8")
x_train["habitat_other"] = (~x_train["habitat"].isin(info["habitat_keys"])).astype("int8")
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/773563372.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["habitat"].fillna(most_freq, inplace=True)

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0             NaN          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color   stem-height    stem-width has-ring ring-type habitat  \
# 1249285          k  8.571480e-07  6.271031e-07        f         f       d
# 1952332          o  4.535067e-07  6.800005e-07        f         f       d
# 2912806          w  2.446106e-07  9.429545e-08        f         f       d
# 136822           w  5.269573e-07  1.092447e-06        f         f       d
# 552456           y  3.753392e-07  4.312292e-07        f         f       d
# ...            ...           ...           ...      ...       ...     ...
# 2249467          w  6.293838e-07  1.055649e-06        f         f       d
# 963395           b  4.036412e-07  4.906430e-07        f         f       d
# 2215104          g  3.645574e-07  8.126275e-08        f         f       d
# 1484405          w  2.338289e-07  3.081851e-07        f         f       d
# 305711           g  3.328861e-07  4.845100e-07        t         r       m
#
#          ... has-ring_flag  ring-type_f  ring-type_n  ring-type_e  \
# 1249285  ...             0            1            0            0
# 1952332  ...             0            1            0            0
# 2912806  ...             0            1            0            0
# 136822   ...             0            1            0            0
# 552456   ...             0            1            0            0
# ...      ...           ...          ...          ...          ...
# 2249467  ...             0            1            0            0
# 963395   ...             0            1            0            0
# 2215104  ...             0            1            0            0
# 1484405  ...             0            1            0            0
# 305711   ...             1            0            0            0
#
#          ring-type_other  habitat_d habitat_g habitat_l habitat_m  \
# 1249285                0          1         0         0         0
# 1952332                0          1         0         0         0
# 2912806                0          1         0         0         0
# 136822                 0          1         0         0         0
# 552456                 0          1         0         0         0
# ...                  ...        ...       ...       ...       ...
# 2249467                0          1         0         0         0
# 963395                 0          1         0         0         0
# 2215104                0          1         0         0         0
# 1484405                0          1         0         0         0
# 305711                 1          0         0         0         1
#
#         habitat_other
# 1249285             0
# 1952332             0
# 2912806             0
# 136822              0
# 552456              0
# ...               ...
# 2249467             0
# 963395              0
# 2215104             0
# 1484405             0
# 305711              0
#
# [2337708 rows x 34 columns]

# %%
train.drop(["has-ring", "ring-type", "habitat"], axis=1, inplace=True)

# %%
most_freq = x_train["gill-attachment"].mode()[0]
x_train["gill-attachment"].fillna(most_freq, inplace=True)
info["gill-attachment_most_freq"] = most_freq
info["gill-attachment_keys"] = list(x_train["gill-attachment"].value_counts()[:3].index)

for k in info["gill-attachment_keys"]:
    x_train[f"gill-attachment_{k}"] = (x_train["gill-attachment"] == k).astype("int8")

x_train["gill-attachment_other"] = (~x_train["gill-attachment"].isin(info["gill-attachment_keys"])).astype("int8")
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/2560855971.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train["gill-attachment"].fillna(most_freq, inplace=True)

# %%
info["gill-spacing_keys"] = list(x_train["gill-spacing"].value_counts()[:2].index)

for k in info["gill-spacing_keys"]:
    x_train[f"gill-spacing_{k}"] = (x_train["gill-spacing"] == k).astype("int8")

x_train["gill-spacing_other"] = (~x_train["gill-spacing"].isin(info["gill-spacing_keys"])).astype("int8")

# %%
info["gill-color_keys"] = list(x_train["gill-color"].value_counts()[:4].index)

for k in info["gill-color_keys"]:
    x_train[f"gill-color_{k}"] = (x_train["gill-color"] == k).astype("int8")

x_train["gill-color_other"] = (~x_train["gill-color"].isin(info["gill-color_keys"])).astype("int8")

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0               a          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color   stem-height    stem-width has-ring ring-type habitat  \
# 1249285          k  8.571480e-07  6.271031e-07        f         f       d
# 1952332          o  4.535067e-07  6.800005e-07        f         f       d
# 2912806          w  2.446106e-07  9.429545e-08        f         f       d
# 136822           w  5.269573e-07  1.092447e-06        f         f       d
# 552456           y  3.753392e-07  4.312292e-07        f         f       d
# ...            ...           ...           ...      ...       ...     ...
# 2249467          w  6.293838e-07  1.055649e-06        f         f       d
# 963395           b  4.036412e-07  4.906430e-07        f         f       d
# 2215104          g  3.645574e-07  8.126275e-08        f         f       d
# 1484405          w  2.338289e-07  3.081851e-07        f         f       d
# 305711           g  3.328861e-07  4.845100e-07        t         r       m
#
#          ... gill-attachment_x  gill-attachment_other  gill-spacing_c  \
# 1249285  ...                 0                      0               0
# 1952332  ...                 0                      0               1
# 2912806  ...                 0                      0               0
# 136822   ...                 0                      1               1
# 552456   ...                 0                      1               0
# ...      ...               ...                    ...             ...
# 2249467  ...                 0                      1               0
# 963395   ...                 0                      0               0
# 2215104  ...                 0                      0               0
# 1484405  ...                 0                      0               1
# 305711   ...                 0                      1               1
#
#          gill-spacing_d  gill-spacing_other  gill-color_w gill-color_n  \
# 1249285               0                   1             0            0
# 1952332               0                   0             0            0
# 2912806               0                   1             1            0
# 136822                0                   0             1            0
# 552456                0                   1             0            0
# ...                 ...                 ...           ...          ...
# 2249467               0                   1             1            0
# 963395                1                   0             0            0
# 2215104               0                   1             0            0
# 1484405               0                   0             1            0
# 305711                0                   0             0            0
#
#         gill-color_y gill-color_p gill-color_other
# 1249285            0            0                1
# 1952332            0            0                1
# 2912806            0            0                0
# 136822             0            0                0
# 552456             1            0                0
# ...              ...          ...              ...
# 2249467            0            0                0
# 963395             0            0                1
# 2215104            0            0                1
# 1484405            0            0                0
# 305711             0            0                1
#
# [2337708 rows x 46 columns]

# %%
x_train.columns
# Out:
# Index(['cap-diameter', 'does-bruise-or-bleed', 'gill-attachment',
#        'gill-spacing', 'gill-color', 'stem-height', 'stem-width', 'has-ring',
#        'ring-type', 'habitat', 'season', 'cap_shape_x', 'cap_shape_f',
#        'cap_shape_s', 'cap_shape_b', 'cap_shape_other', 'cap-surface-clean',
#        'cap-color-clean', 'gill-attachment-clean', 'gill-spacing-clean',
#        'gill-color-clean', 'stem-color-w', 'stem-color-n', 'stem-color-y',
#        'has-ring_flag', 'ring-type_f', 'ring-type_n', 'ring-type_e',
#        'ring-type_other', 'habitat_d', 'habitat_g', 'habitat_l', 'habitat_m',
#        'habitat_other', 'gill-attachment_a', 'gill-attachment_d',
#        'gill-attachment_x', 'gill-attachment_other', 'gill-spacing_c',
#        'gill-spacing_d', 'gill-spacing_other', 'gill-color_w', 'gill-color_n',
#        'gill-color_y', 'gill-color_p', 'gill-color_other'],
#       dtype='object')

# %%
x_train["season"].isna().sum()
# Out:
# np.int64(0)

# %%
info["season_keys"] = list(x_train["season"].value_counts()[:4].index)
for k in info["season_keys"]:
    x_train[f"season_{k}"] = (x_train["season"] == k).astype("int8")
x_train["season_other"] = (~x_train["season"].isin(info["season_keys"])).astype("int8")
x_train.drop("season", axis=1, inplace=True)

# %%
x_train
# Out:
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 1249285          6.11                     0               a          NaN
# 1952332         10.42                     1               d            c
# 2912806          1.86                     0               a          NaN
# 136822           8.65                     0               s            c
# 552456           4.86                     0               s          NaN
# ...               ...                   ...             ...          ...
# 2249467          8.96                     0               p          NaN
# 963395           7.39                     0               d            d
# 2215104          1.94                     0               a          NaN
# 1484405          3.58                     0               d            c
# 305711           7.23                     0               e            c
#
#         gill-color   stem-height    stem-width has-ring ring-type habitat  \
# 1249285          k  8.571480e-07  6.271031e-07        f         f       d
# 1952332          o  4.535067e-07  6.800005e-07        f         f       d
# 2912806          w  2.446106e-07  9.429545e-08        f         f       d
# 136822           w  5.269573e-07  1.092447e-06        f         f       d
# 552456           y  3.753392e-07  4.312292e-07        f         f       d
# ...            ...           ...           ...      ...       ...     ...
# 2249467          w  6.293838e-07  1.055649e-06        f         f       d
# 963395           b  4.036412e-07  4.906430e-07        f         f       d
# 2215104          g  3.645574e-07  8.126275e-08        f         f       d
# 1484405          w  2.338289e-07  3.081851e-07        f         f       d
# 305711           g  3.328861e-07  4.845100e-07        t         r       m
#
#          ...  gill-color_w  gill-color_n  gill-color_y  gill-color_p  \
# 1249285  ...             0             0             0             0
# 1952332  ...             0             0             0             0
# 2912806  ...             1             0             0             0
# 136822   ...             1             0             0             0
# 552456   ...             0             0             1             0
# ...      ...           ...           ...           ...           ...
# 2249467  ...             1             0             0             0
# 963395   ...             0             0             0             0
# 2215104  ...             0             0             0             0
# 1484405  ...             1             0             0             0
# 305711   ...             0             0             0             0
#
#          gill-color_other season_a season_u season_w season_s season_other
# 1249285                 1        1        0        0        0            0
# 1952332                 1        1        0        0        0            0
# 2912806                 0        0        1        0        0            0
# 136822                  0        0        1        0        0            0
# 552456                  0        0        1        0        0            0
# ...                   ...      ...      ...      ...      ...          ...
# 2249467                 0        1        0        0        0            0
# 963395                  1        0        0        1        0            0
# 2215104                 1        1        0        0        0            0
# 1484405                 0        0        1        0        0            0
# 305711                  1        0        1        0        0            0
#
# [2337708 rows x 50 columns]

# %%
x_test.columns
# Out:
# Index(['cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-color', 'has-ring', 'ring-type',
#        'habitat', 'season'],
#       dtype='object')

# %%
x_test["cap-diameter"] /= info["cap-diameter_mean"]

# %%
x_test
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 430964       0.107685         b           h         n                    f
# 1907082      0.103418         f         NaN         n                    f
# 2626732      0.155126         f           i         n                    f
# 38950        0.111199         s         NaN         n                    t
# 96583        0.304731         x           k         n                    t
# ...               ...       ...         ...       ...                  ...
# 304798       0.138309         x           s         b                    f
# 1796005      0.258544         s         NaN         w                    t
# 104462       0.044680         b           g         w                    f
# 52439        0.055976         b           g         w                    f
# 1610993      0.372755         s           k         n                    f
#
#         gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# 430964              NaN          NaN          k         9.95        6.09
# 1907082               x            c          g         5.70        3.98
# 2626732               e            c          n         4.02       12.81
# 38950                 d            c          b         6.03        6.37
# 96583                 p          NaN          o         7.60       29.43
# ...                 ...          ...        ...          ...         ...
# 304798                x            c          w         6.31        8.18
# 1796005               d            c          w         5.93       21.42
# 104462              NaN            c          n         6.81        3.24
# 52439               NaN            c          n         6.22        3.16
# 1610993               d            c          y         6.19       34.46
#
#         stem-color has-ring ring-type habitat season
# 430964           w        t       NaN       g      w
# 1907082          w        f         f       d      u
# 2626732          w        t         r       w      u
# 38950            n        f         f       d      u
# 96583            y        f         f       d      u
# ...            ...      ...       ...     ...    ...
# 304798           n        f         f       l      a
# 1796005          w        f         f       d      u
# 104462           n        f         f       m      u
# 52439            n        f         f       g      a
# 1610993          n        f         f       d      w
#
# [779237 rows x 15 columns]

# %%
for k in info["cap_shape_keys"]:
    x_test[f"cap_shape_{k}"] = (x_test["cap-shape"] == k).astype("int8")
x_test["cap_shape_other"] = (
    ~x_test["cap-shape"].isin(info["cap_shape_keys"])
).astype("int8")
x_test.drop("cap-shape", axis=1, inplace=True)

# %%
def cp_test(x, cap_surface_dict):
    if pd.isna(x):
        return cap_surface_dict.index[0] 
    elif x in cap_surface_dict.index:
        return x
    else:
        return "other"

# %%
x_test["cap-surface-clean"] = x_test["cap-surface"].apply(lambda x: cp_test(x, info["cap_surface_dict"]))
for k in info["cap_surface_dict"]:
    x_test[f"cap_surface_{k}"] = (x_test["cap-surface"] == k).astype("int8")
x_test["cap_surface_other"] = (~x_test["cap-surface"].isin(info["cap_surface_dict"])).astype("int8")
x_test.drop("cap-surface", axis=1, inplace=True)

# %%
x_test
# Out:
#          cap-diameter cap-color does-bruise-or-bleed gill-attachment  \
# 430964       0.107685         n                    f             NaN
# 1907082      0.103418         n                    f               x
# 2626732      0.155126         n                    f               e
# 38950        0.111199         n                    t               d
# 96583        0.304731         n                    t               p
# ...               ...       ...                  ...             ...
# 304798       0.138309         b                    f               x
# 1796005      0.258544         w                    t               d
# 104462       0.044680         w                    f             NaN
# 52439        0.055976         w                    f             NaN
# 1610993      0.372755         n                    f               d
#
#         gill-spacing gill-color  stem-height  stem-width stem-color has-ring  \
# 430964           NaN          k         9.95        6.09          w        t
# 1907082            c          g         5.70        3.98          w        f
# 2626732            c          n         4.02       12.81          w        t
# 38950              c          b         6.03        6.37          n        f
# 96583            NaN          o         7.60       29.43          y        f
# ...              ...        ...          ...         ...        ...      ...
# 304798             c          w         6.31        8.18          n        f
# 1796005            c          w         5.93       21.42          w        f
# 104462             c          n         6.81        3.24          n        f
# 52439              c          n         6.22        3.16          n        f
# 1610993            c          y         6.19       34.46          n        f
#
#          ... cap_surface_0.13404993499892345 cap_surface_0.11644540863465035  \
# 430964   ...                               0                               0
# 1907082  ...                               0                               0
# 2626732  ...                               0                               0
# 38950    ...                               0                               0
# 96583    ...                               0                               0
# ...      ...                             ...                             ...
# 304798   ...                               0                               0
# 1796005  ...                               0                               0
# 104462   ...                               0                               0
# 52439    ...                               0                               0
# 1610993  ...                               0                               0
#
#         cap_surface_0.10773553691979385  cap_surface_0.08448559210938714  \
# 430964                                0                                0
# 1907082                               0                                0
# 2626732                               0                                0
# 38950                                 0                                0
# 96583                                 0                                0
# ...                                 ...                              ...
# 304798                                0                                0
# 1796005                               0                                0
# 104462                                0                                0
# 52439                                 0                                0
# 1610993                               0                                0
#
#          cap_surface_0.052712738848295394  cap_surface_0.048918965324582946  \
# 430964                                  0                                 0
# 1907082                                 0                                 0
# 2626732                                 0                                 0
# 38950                                   0                                 0
# 96583                                   0                                 0
# ...                                   ...                               ...
# 304798                                  0                                 0
# 1796005                                 0                                 0
# 104462                                  0                                 0
# 52439                                   0                                 0
# 1610993                                 0                                 0
#
#          cap_surface_0.04641594693077726  cap_surface_0.04501235974348422  \
# 430964                                 0                                0
# 1907082                                0                                0
# 2626732                                0                                0
# 38950                                  0                                0
# 96583                                  0                                0
# ...                                  ...                              ...
# 304798                                 0                                0
# 1796005                                0                                0
# 104462                                 0                                0
# 52439                                  0                                0
# 1610993                                0                                0
#
#         cap_surface_0.018340932690499485  cap_surface_other
# 430964                                 0                  1
# 1907082                                0                  1
# 2626732                                0                  1
# 38950                                  0                  1
# 96583                                  0                  1
# ...                                  ...                ...
# 304798                                 0                  1
# 1796005                                0                  1
# 104462                                 0                  1
# 52439                                  0                  1
# 1610993                                0                  1
#
# [779237 rows x 31 columns]

# %%
def cc_test(x, cap_color_dict):
    if pd.isna(x):
        return cap_color_dict.index[0] 
    elif x in cap_color_dict.index:
        return x
    else:
        return "other"

# %%
x_test["cap-color-clean"] = x_test["cap-color"].apply(lambda x: cc_test(x, info["cap_color_dict"]))
for k in info["cap_color_dict"]:
    x_test[f"cap_color_{k}"] = (x_test["cap-color"] == k).astype("int8")
x_test["cap_color_other"] = (~x_test["cap-color"].isin(info["cap_color_dict"])).astype("int8")
x_test.drop("cap-color", axis=1, inplace=True)

# %%
x_test.columns
# Out:
# Index(['cap-diameter', 'does-bruise-or-bleed', 'gill-attachment',
#        'gill-spacing', 'gill-color', 'stem-height', 'stem-width', 'stem-color',
#        'has-ring', 'ring-type', 'habitat', 'season', 'cap_shape_x',
#        'cap_shape_f', 'cap_shape_s', 'cap_shape_b', 'cap_shape_other',
#        'cap-surface-clean', 'cap_surface_0.18826056029020188',
#        'cap_surface_0.15762202350940405', 'cap_surface_0.13404993499892345',
#        'cap_surface_0.11644540863465035', 'cap_surface_0.10773553691979385',
#        'cap_surface_0.08448559210938714', 'cap_surface_0.052712738848295394',
#        'cap_surface_0.048918965324582946', 'cap_surface_0.04641594693077726',
#        'cap_surface_0.04501235974348422', 'cap_surface_0.018340932690499485',
#        'cap_surface_other', 'cap-color-clean', 'cap_color_0.5012129139575797',
#        'cap_color_0.14268636232480336', 'cap_color_0.1398368133026799',
#        'cap_color_0.0775866772646099', 'cap_color_0.07269520541379905',
#        'cap_color_0.06598202773652805', 'cap_color_other'],
#       dtype='object')

# %%
x_test["does-bruise-or-bleed"].fillna(most_freq, inplace=True)
x_test["does-bruise-or-bleed"] = (x_test["does-bruise-or-bleed"] == "t").astype("int8")
x_test
# Out:
# /var/folders/20/zt_g_1mx4w33_23q07h61y1m0000gn/T/ipykernel_29114/3705137055.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_test["does-bruise-or-bleed"].fillna(most_freq, inplace=True)
#          cap-diameter  does-bruise-or-bleed gill-attachment gill-spacing  \
# 430964       0.107685                     0             NaN          NaN
# 1907082      0.103418                     0               x            c
# 2626732      0.155126                     0               e            c
# 38950        0.111199                     0               d            c
# 96583        0.304731                     0               p          NaN
# ...               ...                   ...             ...          ...
# 304798       0.138309                     0               x            c
# 1796005      0.258544                     0               d            c
# 104462       0.044680                     0             NaN            c
# 52439        0.055976                     0             NaN            c
# 1610993      0.372755                     0               d            c
#
#         gill-color  stem-height  stem-width stem-color has-ring ring-type  \
# 430964           k         9.95        6.09          w        t       NaN
# 1907082          g         5.70        3.98          w        f         f
# 2626732          n         4.02       12.81          w        t         r
# 38950            b         6.03        6.37          n        f         f
# 96583            o         7.60       29.43          y        f         f
# ...            ...          ...         ...        ...      ...       ...
# 304798           w         6.31        8.18          n        f         f
# 1796005          w         5.93       21.42          w        f         f
# 104462           n         6.81        3.24          n        f         f
# 52439            n         6.22        3.16          n        f         f
# 1610993          y         6.19       34.46          n        f         f
#
#          ... cap_surface_0.018340932690499485 cap_surface_other  \
# 430964   ...                                0                 1
# 1907082  ...                                0                 1
# 2626732  ...                                0                 1
# 38950    ...                                0                 1
# 96583    ...                                0                 1
# ...      ...                              ...               ...
# 304798   ...                                0                 1
# 1796005  ...                                0                 1
# 104462   ...                                0                 1
# 52439    ...                                0                 1
# 1610993  ...                                0                 1
#
#          cap-color-clean  cap_color_0.5012129139575797  \
# 430964                 n                             0
# 1907082                n                             0
# 2626732                n                             0
# 38950                  n                             0
# 96583                  n                             0
# ...                  ...                           ...
# 304798             other                             0
# 1796005                w                             0
# 104462                 w                             0
# 52439                  w                             0
# 1610993                n                             0
#
#          cap_color_0.14268636232480336  cap_color_0.1398368133026799  \
# 430964                               0                             0
# 1907082                              0                             0
# 2626732                              0                             0
# 38950                                0                             0
# 96583                                0                             0
# ...                                ...                           ...
# 304798                               0                             0
# 1796005                              0                             0
# 104462                               0                             0
# 52439                                0                             0
# 1610993                              0                             0
#
#          cap_color_0.0775866772646099 cap_color_0.07269520541379905  \
# 430964                              0                             0
# 1907082                             0                             0
# 2626732                             0                             0
# 38950                               0                             0
# 96583                               0                             0
# ...                               ...                           ...
# 304798                              0                             0
# 1796005                             0                             0
# 104462                              0                             0
# 52439                               0                             0
# 1610993                             0                             0
#
#          cap_color_0.06598202773652805  cap_color_other
# 430964                               0                1
# 1907082                              0                1
# 2626732                              0                1
# 38950                                0                1
# 96583                                0                1
# ...                                ...              ...
# 304798                               0                1
# 1796005                              0                1
# 104462                               0                1
# 52439                                0                1
# 1610993                              0                1
#
# [779237 rows x 38 columns]

# %%
def ga_test(x, gill_att_dict):
    if pd.isna(x):
        return gill_att_dict.index[0]  
    elif x in gill_att_dict.index:
        return x
    else:
        return "other"

# %%
x_test["gill-attachment"] = x_test["gill-attachment"].apply(lambda x: ga_test(x, gill_att_dict))
for k in info["gill-attachment-dict"]:
    x_test[f"gill_attachment_{k}"] = (x_test["gill-attachment"] == k).astype("int8")
x_test["gill-attachment_other"] = (~x_test["gill-attachment"].isin(info["gill-attachment-dict"])).astype("int8")
x_test.drop("gill-attachment", axis=1, inplace=True)

# %%
x_test
# Out:
#          cap-diameter  does-bruise-or-bleed gill-spacing gill-color  \
# 430964       0.107685                     0          NaN          k
# 1907082      0.103418                     0            c          g
# 2626732      0.155126                     0            c          n
# 38950        0.111199                     0            c          b
# 96583        0.304731                     0          NaN          o
# ...               ...                   ...          ...        ...
# 304798       0.138309                     0            c          w
# 1796005      0.258544                     0            c          w
# 104462       0.044680                     0            c          n
# 52439        0.055976                     0            c          n
# 1610993      0.372755                     0            c          y
#
#          stem-height  stem-width stem-color has-ring ring-type habitat  ...  \
# 430964          9.95        6.09          w        t       NaN       g  ...
# 1907082         5.70        3.98          w        f         f       d  ...
# 2626732         4.02       12.81          w        t         r       w  ...
# 38950           6.03        6.37          n        f         f       d  ...
# 96583           7.60       29.43          y        f         f       d  ...
# ...              ...         ...        ...      ...       ...     ...  ...
# 304798          6.31        8.18          n        f         f       l  ...
# 1796005         5.93       21.42          w        f         f       d  ...
# 104462          6.81        3.24          n        f         f       m  ...
# 52439           6.22        3.16          n        f         f       g  ...
# 1610993         6.19       34.46          n        f         f       d  ...
#
#         cap_color_0.06598202773652805  cap_color_other  gill-attachment-clean  \
# 430964                              0                1                      e
# 1907082                             0                1                      x
# 2626732                             0                1                      e
# 38950                               0                1                      d
# 96583                               0                1                      p
# ...                               ...              ...                    ...
# 304798                              0                1                      x
# 1796005                             0                1                      d
# 104462                              0                1                      a
# 52439                               0                1                      s
# 1610993                             0                1                      d
#
#          gill_attachment_0.2611152639305519  \
# 430964                                    0
# 1907082                                   0
# 2626732                                   0
# 38950                                     0
# 96583                                     0
# ...                                     ...
# 304798                                    0
# 1796005                                   0
# 104462                                    0
# 52439                                     0
# 1610993                                   0
#
#          gill_attachment_0.23830711663813625  \
# 430964                                     0
# 1907082                                    0
# 2626732                                    0
# 38950                                      0
# 96583                                      0
# ...                                      ...
# 304798                                     0
# 1796005                                    0
# 104462                                     0
# 52439                                      0
# 1610993                                    0
#
#          gill_attachment_0.14588315368344298  \
# 430964                                     0
# 1907082                                    0
# 2626732                                    0
# 38950                                      0
# 96583                                      0
# ...                                      ...
# 304798                                     0
# 1796005                                    0
# 104462                                     0
# 52439                                      0
# 1610993                                    0
#
#         gill_attachment_0.12210745339404001  \
# 430964                                    0
# 1907082                                   0
# 2626732                                   0
# 38950                                     0
# 96583                                     0
# ...                                     ...
# 304798                                    0
# 1796005                                   0
# 104462                                    0
# 52439                                     0
# 1610993                                   0
#
#          gill_attachment_0.11959203133275302  \
# 430964                                     0
# 1907082                                    0
# 2626732                                    0
# 38950                                      0
# 96583                                      0
# ...                                      ...
# 304798                                     0
# 1796005                                    0
# 104462                                     0
# 52439                                      0
# 1610993                                    0
#
#          gill_attachment_0.11299498102107584  gill-attachment_other
# 430964                                     0                      1
# 1907082                                    0                      1
# 2626732                                    0                      1
# 38950                                      0                      1
# 96583                                      0                      1
# ...                                      ...                    ...
# 304798                                     0                      1
# 1796005                                    0                      1
# 104462                                     0                      1
# 52439                                      0                      1
# 1610993                                    0                      1
#
# [779237 rows x 45 columns]

# %%
info["gill-spacing-dict"] = gill_sp_dict        
def gs_test(x, gill_sp_dict):
    if pd.isna(x):
        return gill_sp_dict.index[0] 
    elif x in gill_sp_dict.index:
        return x
    else:
        return "other"
x_test["gill-spacing"] = x_test["gill-spacing"].apply(lambda x: gs_test(x, gill_sp_dict))
for k in info["gill-spacing-dict"]:
    x_test[f"gill_spacing_{k}"] = (x_test["gill-spacing"] == k).astype("int8")
x_test["gill-spacing_other"] = (~x_test["gill-spacing"].isin(info["gill-spacing-dict"])).astype("int8")
x_test.drop("gill-spacing", axis=1, inplace=True)

# %%
x_test
# Out:
#          cap-diameter  does-bruise-or-bleed gill-color  stem-height  \
# 430964       0.107685                     0          k         9.95
# 1907082      0.103418                     0          g         5.70
# 2626732      0.155126                     0          n         4.02
# 38950        0.111199                     0          b         6.03
# 96583        0.304731                     0          o         7.60
# ...               ...                   ...        ...          ...
# 304798       0.138309                     0          w         6.31
# 1796005      0.258544                     0          w         5.93
# 104462       0.044680                     0          n         6.81
# 52439        0.055976                     0          n         6.22
# 1610993      0.372755                     0          y         6.19
#
#          stem-width stem-color has-ring ring-type habitat season  ...  \
# 430964         6.09          w        t       NaN       g      w  ...
# 1907082        3.98          w        f         f       d      u  ...
# 2626732       12.81          w        t         r       w      u  ...
# 38950          6.37          n        f         f       d      u  ...
# 96583         29.43          y        f         f       d      u  ...
# ...             ...        ...      ...       ...     ...    ...  ...
# 304798         8.18          n        f         f       l      a  ...
# 1796005       21.42          w        f         f       d      u  ...
# 104462         3.24          n        f         f       m      u  ...
# 52439          3.16          n        f         f       g      a  ...
# 1610993       34.46          n        f         f       d      w  ...
#
#          gill_attachment_0.12210745339404001  \
# 430964                                     0
# 1907082                                    0
# 2626732                                    0
# 38950                                      0
# 96583                                      0
# ...                                      ...
# 304798                                     0
# 1796005                                    0
# 104462                                     0
# 52439                                      0
# 1610993                                    0
#
#          gill_attachment_0.11959203133275302  \
# 430964                                     0
# 1907082                                    0
# 2626732                                    0
# 38950                                      0
# 96583                                      0
# ...                                      ...
# 304798                                     0
# 1796005                                    0
# 104462                                     0
# 52439                                      0
# 1610993                                    0
#
#          gill_attachment_0.11299498102107584  gill-attachment_other  \
# 430964                                     0                      1
# 1907082                                    0                      1
# 2626732                                    0                      1
# 38950                                      0                      1
# 96583                                      0                      1
# ...                                      ...                    ...
# 304798                                     0                      1
# 1796005                                    0                      1
# 104462                                     0                      1
# 52439                                      0                      1
# 1610993                                    0                      1
#
#          gill_spacing_0.7159222079300046 gill_spacing_0.21964731143300087  \
# 430964                                 0                                0
# 1907082                                0                                0
# 2626732                                0                                0
# 38950                                  0                                0
# 96583                                  0                                0
# ...                                  ...                              ...
# 304798                                 0                                0
# 1796005                                0                                0
# 104462                                 0                                0
# 52439                                  0                                0
# 1610993                                0                                0
#
#          gill_spacing_0.06440178460615774  \
# 430964                                  0
# 1907082                                 0
# 2626732                                 0
# 38950                                   0
# 96583                                   0
# ...                                   ...
# 304798                                  0
# 1796005                                 0
# 104462                                  0
# 52439                                   0
# 1610993                                 0
#
#          gill_spacing_1.0043610792864157e-05  \
# 430964                                     0
# 1907082                                    0
# 2626732                                    0
# 38950                                      0
# 96583                                      0
# ...                                      ...
# 304798                                     0
# 1796005                                    0
# 104462                                     0
# 52439                                      0
# 1610993                                    0
#
#          gill_spacing_9.32621002194529e-06  gill-spacing_other
# 430964                                   0                   1
# 1907082                                  0                   1
# 2626732                                  0                   1
# 38950                                    0                   1
# 96583                                    0                   1
# ...                                    ...                 ...
# 304798                                   0                   1
# 1796005                                  0                   1
# 104462                                   0                   1
# 52439                                    0                   1
# 1610993                                  0                   1
#
# [779237 rows x 50 columns]

# %%
info["gill-color-dict"] = gill_c_dict        
def gc_test(x, gill_c_dict):
    if pd.isna(x):
        return gill_c_dict.index[0] 
    elif x in gill_c_dict.index:
        return x
    else:
        return "other"
x_test["gill-color"] = x_test["gill-color"].apply(lambda x: gc_test(x, gill_c_dict))
for k in info["gill-color-dict"]:
    x_test[f"gill_color_{k}"] = (x_test["gill-color"] == k).astype("int8")
x_test["gill-color_other"] = (~x_test["gill-color"].isin(info["gill-color-dict"])).astype("int8")
x_test.drop("gill-color", axis=1, inplace=True)

# %%
x_test
# Out:
#          cap-diameter  does-bruise-or-bleed  stem-height  stem-width  \
# 430964       0.107685                     0         9.95        6.09
# 1907082      0.103418                     0         5.70        3.98
# 2626732      0.155126                     0         4.02       12.81
# 38950        0.111199                     0         6.03        6.37
# 96583        0.304731                     0         7.60       29.43
# ...               ...                   ...          ...         ...
# 304798       0.138309                     0         6.31        8.18
# 1796005      0.258544                     0         5.93       21.42
# 104462       0.044680                     0         6.81        3.24
# 52439        0.055976                     0         6.22        3.16
# 1610993      0.372755                     0         6.19       34.46
#
#         stem-color has-ring ring-type habitat season  cap_shape_x  ...  \
# 430964           w        t       NaN       g      w            0  ...
# 1907082          w        f         f       d      u            0  ...
# 2626732          w        t         r       w      u            0  ...
# 38950            n        f         f       d      u            0  ...
# 96583            y        f         f       d      u            1  ...
# ...            ...      ...       ...     ...    ...          ...  ...
# 304798           n        f         f       l      a            1  ...
# 1796005          w        f         f       d      u            0  ...
# 104462           n        f         f       m      u            0  ...
# 52439            n        f         f       g      a            0  ...
# 1610993          n        f         f       d      w            0  ...
#
#          gill_spacing_1.0043610792864157e-05  \
# 430964                                     0
# 1907082                                    0
# 2626732                                    0
# 38950                                      0
# 96583                                      0
# ...                                      ...
# 304798                                     0
# 1796005                                    0
# 104462                                     0
# 52439                                      0
# 1610993                                    0
#
#          gill_spacing_9.32621002194529e-06  gill-spacing_other  \
# 430964                                   0                   1
# 1907082                                  0                   1
# 2626732                                  0                   1
# 38950                                    0                   1
# 96583                                    0                   1
# ...                                    ...                 ...
# 304798                                   0                   1
# 1796005                                  0                   1
# 104462                                   0                   1
# 52439                                    0                   1
# 1610993                                  0                   1
#
#          gill_color_0.35074476706114943 gill_color_0.20436448300345475  \
# 430964                                0                              0
# 1907082                               0                              0
# 2626732                               0                              0
# 38950                                 0                              0
# 96583                                 0                              0
# ...                                 ...                            ...
# 304798                                0                              0
# 1796005                               0                              0
# 104462                                0                              0
# 52439                                 0                              0
# 1610993                               0                              0
#
#          gill_color_0.17696026654557043  gill_color_0.1293609078204932  \
# 430964                                0                              0
# 1907082                               0                              0
# 2626732                               0                              0
# 38950                                 0                              0
# 96583                                 0                              0
# ...                                 ...                            ...
# 304798                                0                              0
# 1796005                               0                              0
# 104462                                0                              0
# 52439                                 0                              0
# 1610993                               0                              0
#
#          gill_color_0.07956174529142132  gill_color_0.059007830277910886  \
# 430964                                0                                0
# 1907082                               0                                0
# 2626732                               0                                0
# 38950                                 0                                0
# 96583                                 0                                0
# ...                                 ...                              ...
# 304798                                0                                0
# 1796005                               0                                0
# 104462                                0                                0
# 52439                                 0                                0
# 1610993                               0                                0
#
#          gill-color_other
# 430964                  1
# 1907082                 1
# 2626732                 1
# 38950                   1
# 96583                   1
# ...                   ...
# 304798                  1
# 1796005                 1
# 104462                  1
# 52439                   1
# 1610993                 1
#
# [779237 rows x 56 columns]
